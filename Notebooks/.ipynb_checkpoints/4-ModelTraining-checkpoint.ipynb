# %% [markdown]
# ### ✅ Importing libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder, Normalizer, StandardScaler

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### ✅ Getting raw data from github repository

# %%
Raw_Data_Url = "https://raw.githubusercontent.com/Alireza-Esp/CPP_Model/main/Data/CarsData.csv"

# %%
Raw_Data = pd.read_csv(Raw_Data_Url)

# %%
Raw_Data.head(20)
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             I10  2017   7495       Manual    11630   Petrol  145  60.1
# 1            Polo  2017  10989       Manual     9200   Petrol  145  58.9
# 2        2 Series  2019  27990    Semi-Auto     1614   Diesel  145  49.6
# 3    Yeti Outdoor  2017  12495       Manual    30960   Diesel  150  62.8
# 4          Fiesta  2017   7999       Manual    19353   Petrol  125  54.3
# 5            C-HR  2019  26791    Automatic     2373   Hybrid  135  74.3
# 6            Kuga  2019  17990       Manual     7038   Petrol  145  34.4
# 7          Tiguan  2019  27490    Semi-Auto     3000   Petrol  145  30.4
# 8          Fiesta  2018   9891       Manual    31639   Petrol  145  65.7
# 9         A Class  2017  17498       Manual     9663   Diesel   30  62.8
# 10           Kuga  2017  16500    Semi-Auto    30000   Diesel  145  54.3
# 11       1 Series  2016  10550       Manual    40313   Diesel    0  78.5
# 12             Up  2017   7990       Manual     9179   Petrol  145  64.2
# 13           Golf  2019  11980       Manual    14621   Petrol  145  49.6
# 14          Corsa  2017   7499       Manual    25000   Petrol  150  55.4
# 15           RAV4  2016  20790    Automatic    32196   Hybrid   20  55.4
# 16         Fiesta  2017  10490       Manual    16087   Petrol    0  65.7
# 17      GLA Class  2016  15600    Automatic    42844   Diesel   30  64.2
# 18           Golf  2017  17750       Manual    27125   Diesel   20  67.3
# 19           Aygo  2016   7130       Manual    23971   Petrol    0  69.0
#
#     engineSize Manufacturer
# 0          1.0       hyundi
# 1          1.0   volkswagen
# 2          2.0          BMW
# 3          2.0        skoda
# 4          1.2         ford
# 5          1.8       toyota
# 6          1.5         ford
# 7          2.0   volkswagen
# 8          1.0         ford
# 9          2.1         merc
# 10         2.0         ford
# 11         1.5          BMW
# 12         1.0   volkswagen
# 13         1.0   volkswagen
# 14         1.4     vauxhall
# 15         2.5       toyota
# 16         1.0         ford
# 17         2.1         merc
# 18         2.0   volkswagen
# 19         1.0       toyota

# %% [markdown]
# ### ✅ Preprocessing Raw Data

# %% [markdown]
# #### 🔹 Fixing some problems in dataset

# %%
Raw_Data.model = Raw_Data.model.str[1:]

# %%
Raw_Data.drop(index=[32875, 35888, 16899, 87943, 52951], inplace=True)

# %%
Raw_Data = Raw_Data.reset_index()

# %%
Temp_Raw_Data = Raw_Data.copy()
del Raw_Data

Raw_Data = pd.DataFrame()
for i in ["Manufacturer", "model", "transmission", "fuelType", "year", "engineSize", "mileage", "mpg", "tax", "price"]:
    Raw_Data[i] = Temp_Raw_Data[[i]]

del Temp_Raw_Data

Raw_Data
# Out:
#       Manufacturer         model transmission fuelType  year  engineSize  \
# 0           hyundi           I10       Manual   Petrol  2017         1.0
# 1       volkswagen          Polo       Manual   Petrol  2017         1.0
# 2              BMW      2 Series    Semi-Auto   Diesel  2019         2.0
# 3            skoda  Yeti Outdoor       Manual   Diesel  2017         2.0
# 4             ford        Fiesta       Manual   Petrol  2017         1.2
# ...            ...           ...          ...      ...   ...         ...
# 97702         ford        Fiesta    Automatic   Petrol  2017         1.0
# 97703          BMW      3 Series       Manual   Diesel  2014         2.0
# 97704         ford        Fiesta       Manual   Petrol  2017         1.2
# 97705     vauxhall         Astra    Automatic   Petrol  2017         1.4
# 97706     vauxhall   Grandland X       Manual   Diesel  2019         1.5
#
#        mileage   mpg  tax  price
# 0        11630  60.1  145   7495
# 1         9200  58.9  145  10989
# 2         1614  49.6  145  27990
# 3        30960  62.8  150  12495
# 4        19353  54.3  125   7999
# ...        ...   ...  ...    ...
# 97702     8337  54.3  145  10447
# 97703    25372  61.4   30  14995
# 97704    19910  54.3  125   8950
# 97705    24468  50.4  125  10700
# 97706    10586  48.7  150  15798
#
# [97707 rows x 10 columns]

# %% [markdown]
# #### 🔹 Splitting Raw Data to Categorical and Numerical X and y sets

# %%
X_cat = Raw_Data.loc[:, ["Manufacturer", "model", "transmission", "fuelType"]]
X_num = Raw_Data.loc[:, ["year", "engineSize", "mileage", "mpg", "tax"]]
y = Raw_Data.loc[:, ["price"]].values

# %% [markdown]
# #### 🔹 Encoding Categorical feutures

# %%
ohe = OneHotEncoder()
X_cat = pd.DataFrame(ohe.fit_transform(X_cat).toarray())

# %% [markdown]
# #### 🔹 Forming X

# %% [markdown]
# 0 - 208 : Manufacturer, model, transmission, fuelType [Encoded] \
# 209 : year \
# 210 : engineSize \
# 211 : mileage \
# 212 : mpg \
# 213 : tax

# %%
X = X_cat.join(X_num).to_numpy()
X
# Out:
# array([[0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 1.1630e+04, 6.0100e+01,
#         1.4500e+02],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 9.2000e+03, 5.8900e+01,
#         1.4500e+02],
#        [0.0000e+00, 1.0000e+00, 0.0000e+00, ..., 1.6140e+03, 4.9600e+01,
#         1.4500e+02],
#        ...,
#        [0.0000e+00, 0.0000e+00, 1.0000e+00, ..., 1.9910e+04, 5.4300e+01,
#         1.2500e+02],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 2.4468e+04, 5.0400e+01,
#         1.2500e+02],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 1.0586e+04, 4.8700e+01,
#         1.5000e+02]])

# %% [markdown]
# #### 🔹 Splitting X and y to TrainSet and TestSet

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.18, random_state=0)

# %% [markdown]
# #### 🔹 Scaling Datas

# %%
#no = Normalizer()
#X_train = no.fit_transform(X_train)

# %%
ss = StandardScaler()
X_train = ss.fit_transform(X_train)

# %% [markdown]
# ### ✅ Training Model

# %%
CPP_Model = RandomForestRegressor()
CPP_Model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# #### 🔹 Predicting on Test Datas

# %%
y_pred = CPP_Model.predict(ss.transform(X_test))

# %% [markdown]
# #### 🔹 Evaluating Model (R2-Score)

# %%
print(str(r2_score(y_test, y_pred).round(3) * 100) + "%")
# Out:
# 95.7%
